# %%
import dicom

# %%
rs=dicom.read_file('joue/rs_joue.dcm')

# %%
print rs
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20180705'
# (0008, 0013) Instance Creation Time              TM: '172556.157000'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.4.950586737223.247115.20161025172843
# (0008, 0020) Study Date                          DA: '20161017'
# (0008, 0030) Study Time                          TM: '174012'
# (0008, 0050) Accession Number                    SH: '102954406'
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: 'CHIRA^CIPRIAN'
# (0008, 1010) Station Name                        SH: 'SRVVARIAN-DB'
# (0008, 1030) Study Description                   LO: 'TDM therapie SPC'
# ...

# %%
for roi in rs.StructureSetROISequence:
    print 'name:', roi.ROIName, ' ; number:' , roi.ROINumber
print rs.StructureSetROISequence
# Out:
# name: CONTOUR EXTERNE  ; number: 1
# name: OeilG  ; number: 3
# name: CTV_  ; number: 2
# name: cerclage  ; number: 4
# [(3006, 0022) ROI Number                          IS: '1'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.2.840.113619.2.278.3.3523880722.475.1476683587.386.9360.1
# (3006, 0026) ROI Name                            LO: 'CONTOUR EXTERNE'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'(3006, 0022) ROI Number                          IS: '3'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.2.840.113619.2.278.3.3523880722.475.1476683587.386.9360.1
# (3006, 0026) ROI Name                            LO: 'OeilG'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'(3006, 0022) ROI Number                          IS: '2'
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.2.840.113619.2.278.3.3523880722.475.1476683587.386.9360.1
# (3006, 0026) ROI Name                            LO: 'CTV_'
# ...

# %%
print rs.ROIContourSequence[0].ContourSequence[0].ContourData
# Out:
# ['12.21', '-60.26', '-175', '14.16', '-60.43', '-175', '16.11', '-60.55', '-175', '18.07', '-60.6', '-175', '20.02', '-60.6', '-175', '21.97', '-60.55', '-175', '23.93', '-60.49', '-175', '25.88', '-60.32', '-175', '27.83', '-60.09', '-175', '28.03', '-60.06', '-175', '29.79', '-59.79', '-175', '31.74', '-59.46', '-175', '33.69', '-59.05', '-175', '35.64', '-58.61', '-175', '37.49', '-58.11', '-175', '37.6', '-58.08', '-175', '39.55', '-57.53', '-175', '41.5', '-56.92', '-175', '43.46', '-56.24', '-175', '43.72', '-56.15', '-175', '45.41', '-55.55', '-175', '47.36', '-54.8', '-175', '48.79', '-54.2', '-175', '49.32', '-53.97', '-175', '51.27', '-53.13', '-175', '53.22', '-52.28', '-175', '53.3', '-52.25', '-175', '55.18', '-51.4', '-175', '57.13', '-50.52', '-175', '57.62', '-50.29', '-175', '59.08', '-49.61', '-175', '61.03', '-48.7', '-175', '61.8', '-48.34', '-175', '62.99', '-47.79', '-175', '64.94', '-46.92', '-175', '66.13', '-46.39', '-175', '66.89', '-46.03', '-175', '68.85',
# ...
